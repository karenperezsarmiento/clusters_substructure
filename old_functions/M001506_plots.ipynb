# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
import matplotlib.pyplot as plt
from astropy.convolution import Gaussian2DKernel
from scipy.signal import convolve as scipy_convolve
import numpy as np
from astropy.convolution import convolve

# %%
MOO1506_theta1_5__theta2_10=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_10")
MOO1506_theta1_5__theta2_875=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_8.75")
MOO1506_theta1_5__theta2_15=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_15")
MOO1506_theta1_5__theta2_20=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_20")
MOO1506_theta1_5__theta2_25=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_25")
MOO1506_theta1_5__theta2_30=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_30")
MOO1506_theta1_5__theta2_35=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_35")
MOO1506_theta1_5__theta2_40=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_40")
MOO1506_theta1_5__theta2_45=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_45")
MOO1506_theta1_5__theta2_50=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_5__theta2_50")
MOO1506_theta1_1d5__theta2_10=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_10")
MOO1506_theta1_1d5__theta2_875=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_8.75")
MOO1506_theta1_1d5__theta2_15=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_15")
MOO1506_theta1_1d5__theta2_20=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_20")
MOO1506_theta1_1d5__theta2_25=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_25")
MOO1506_theta1_1d5__theta2_30=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_30")
MOO1506_theta1_1d5__theta2_35=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_35")
MOO1506_theta1_1d5__theta2_40=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_40")
MOO1506_theta1_1d5__theta2_45=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_45")
MOO1506_theta1_1d5__theta2_50=np.loadtxt("/users/ksarmien/Documents/clusters_substructure/diff_Gauss_img_map_MOO1506_theta1_1.5__theta2_50")

# %%
fig, axs = plt.subplots(2,5)
axs[0,0].imshow(MOO1506_theta1_5__theta2_10,cmap="RdBu")
axs[0,1].imshow(MOO1506_theta1_5__theta2_875,cmap="RdBu")
axs[0,2].imshow(MOO1506_theta1_5__theta2_15,cmap="RdBu")
axs[0,3].imshow(MOO1506_theta1_5__theta2_20,cmap="RdBu")
axs[0,4].imshow(MOO1506_theta1_5__theta2_25,cmap="RdBu")
axs[1,0].imshow(MOO1506_theta1_5__theta2_30,cmap="RdBu")
axs[1,1].imshow(MOO1506_theta1_5__theta2_35,cmap="RdBu")
axs[1,2].imshow(MOO1506_theta1_5__theta2_40,cmap="RdBu")
axs[1,3].imshow(MOO1506_theta1_5__theta2_45,cmap="RdBu")
axs[1,4].imshow(MOO1506_theta1_5__theta2_50,cmap="RdBu")
